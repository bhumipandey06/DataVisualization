# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib Basics

# %%
x=np.linspace(1,5,11)
x
# Out:
# array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ])

# %%
y=x**2
y
# Out:
# array([ 1.  ,  1.96,  3.24,  4.84,  6.76,  9.  , 11.56, 14.44, 17.64,
#        21.16, 25.  ])

# %%
plt.plot(x,y)
plt.title("Plot-Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# SubPlots in Matplotlib

# %%
plt.subplot(2,2,1)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y**2,x)
plt.subplot(2,2,2)
plt.plot(x**2,y)

# %% [markdown]
# Object Oriented Way

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 = fig.add_axes([0.2,0.7,.5,0.3])
axis2.plot(x,y)

# %% [markdown]
# Types of Plots

# %%
plt.scatter(x,y)

# %%
from random import sample 
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([10.,  8., 13.,  8.,  8.,  9.,  9., 15., 10., 10.]),
#  array([  5. , 103.4, 201.8, 300.2, 398.6, 497. , 595.4, 693.8, 792.2,
#         890.6, 989. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d81da3af30>,
#   <matplotlib.lines.Line2D at 0x1d81da38770>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d81da3a120>,
#   <matplotlib.lines.Line2D at 0x1d81daf3e60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d81dccd7c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d81daf2150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d81daf0e00>],
#  'means': []}

# %% [markdown]
# Saving plots

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("1stPlot.png")

# %% [markdown]
# Working with image
